# %% [markdown]
# # Bắt đầu

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Bài giải
# Từ đề bài ta có tập nền X = {'week 1','week 2','week 3','week 4'}

# %% [markdown]
# # Kết thúc
