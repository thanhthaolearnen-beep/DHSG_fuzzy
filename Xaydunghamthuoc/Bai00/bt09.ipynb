# %% [markdown]
# # Bắt đầu

# %% [markdown]
# ## **Bài 9.**
# Nước tồn tại ở ba trạng thái vật lý: rắn (băng), lỏng (nước), và khí (hơi nước). Ba trạng thái này phụ thuộc vào nhiệt độ. Hãy vẽ hàm thuộc cho ba trạng thái của nước theo thang nhiệt độ (°C hoặc °F).

# %% [markdown]
# ## **Bài Làm**

# %% [markdown]
# # Kết thúc
